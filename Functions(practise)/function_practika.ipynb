# %% [markdown]
# Вы работаете секретарем и вам постоянно приходят различные документы. Вы должны быть очень внимательны, чтобы не потерять ни один документ. Каталог документов хранится в следующем виде:

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

# %%
def print_documents(documents):
    for doc in documents:
        print(doc)

# %% [markdown]
# Перечень полок, на которых находятся документы хранится в следующем виде:

# %%
directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

# %%
def print_directories(directories):
    print('Каталог документов :')
    for key,value in directories.items():
        print(key,value)
    print('Перечень полок:')
    for i in documents:
        print(i)
#------------------------------------------------------------------------ 
def People(Num):
    for doc in documents:
        if doc['number']==Num:
            return doc['name']
    return 'Не найдено'
#------------------------------------------------------------------------    
def Shelf(Num):
    for et,doc in directories.items():
        if Num in doc:
            return et
        else:
            continue
    return 0
#------------------------------------------------------------------------ 
def List():
    docs = [(i['type'],i['number'],i['name']) for i in documents]
    for f in docs:
        print(f'{f[0]} "{f[1]}" "{f[2]}"')
#------------------------------------------------------------------------ 
def AddShelf(shelfnum):
    if shelfnum in directories.keys():
        print('Полка уже существует')
    else:
        directories[str(shelfnum)] = []
        print('Полка добавлена')
#------------------------------------------------------------------------ 
def DeleteShelf(): # ds
    sh = input('Введите номер полки')
    if sh in directories.keys():
        del(directories[str(sh)])
        return 'Полка удалена'
    else:
        return 'Ошибка: полка не найдена'
#------------------------------------------------------------------------ 
def Delete(Num):
    if People(Num)=='Не найдено':
        print('Такого документа не существует')
        return 0
    else:
        for i,doc in enumerate(documents):
            if doc['number'] == Num:
                del(documents[i])
        directories[Shelf(Num)].remove(Num)
        print('Документ удален')
    
#------------------------------------------------------------------------ 
def Move(Num):
    n = Shelf(Num)
    if n == 0:
        print('Такого документа не существует')
    else:
        directories[str(n)].remove(str(Num))
        shelfnum = str(input('Введите номер полки, на которую хотите переместить'))
        if shelfnum in directories.keys():
            directories[shelfnum].append(str(Num))
        else:
            q = input('Такой полки не существует. Хотите добавить?(Да/Нет))')
            if q == 'Да':
                shelfnum = str(input('Введите номер новой полки: '))
                AddShelf(shelfnum)
                directories[shelfnum].append(str(Num))
            if q == 'Нет':
                return 'Возврат в меню...'
            
#------------------------------------------------------------------------ 
def Add():
    newname = str(input('Введите name: '))
    numb = str(input('Введите номер документа: '))
    doctype = str(input('Введите тип документа: '))
    shelfnum = str(input('Введите номер полки: '))
    if shelfnum in directories.keys():
        directories[shelfnum].append(numb)
        newdoc = {'type': doctype, 'number': numb, 'name': newname}
        documents.append(newdoc)
    else:
        q = input('Такой полки не существует. Хотите добавить?(Да/Нет)): ')
        if q == 'Да':
            AddShelf(shelfnum)
            print(f'Добавлена полка №{shelfnum}')
            directories[shelfnum].append(numb)
        if q == 'Нет':
            print('Возврат в меню...')
#------------------------------------------------------------------------ 
def main():
    while True:
        print(' Команды: p,s,l,as,d,m,add,out,exit')
        user_input = input('Введите команду: ')
        if user_input == 'p':
            Num = str(input('Введите номер документа: '))
            print(People(Num))
        elif user_input == 's':
            Num = str(input('Введите номер документа: '))
            num = Shelf(Num)
            if num != 0:
                print(f'Полка №{num}')
            else:
                print('Документ не найден!')
        elif user_input == 'l':
            List()
        elif user_input == 'as':
            shelfnum = str(input('Введите номер новой полки: '))
            AddShelf(shelfnum)
        elif user_input == 'd':
            Num = str(input('Введите номер документа: '))
            Delete(Num)
        elif user_input == 'm':
            Num = str(input('Введите номер документа: '))
            Move(Num)
        elif user_input == 'add':
            Add()
        elif user_input == 'out':
            print_directories(directories)
        elif user_input == 'exit':
            break
        elif user_input == 'dp':
            d = str(input('Введите номер полки которую хотите удалить: '))
            if d in directories.keys():
                del(directories[d])
            else:
                print('Полка не найдена')
        print('----------------------------------------------')
main()
# Out:
#  Команды: p,s,l,as,d,m,add,out,exit
# Введите команду: out
# Каталог документов :
# 1 ['11-2']
# 2 ['10006']
# 3 []
# 5 []
# 10 ['7874 342546']
# Перечень полок:
# {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
# {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'}
# {'type': 'passport', 'number': '7874 342546', 'name': 'Aydar Yulchurin'}
# ----------------------------------------------
#  Команды: p,s,l,as,d,m,add,out,exit
# Введите команду: p
# Введите номер документа: 7874 342546
# Aydar Yulchurin
# ----------------------------------------------
#  Команды: p,s,l,as,d,m,add,out,exit
# Введите команду: s
# Введите номер документа: 10006
# Полка №2
# ----------------------------------------------
#  Команды: p,s,l,as,d,m,add,out,exit
# Введите команду: l
# insurance "10006" "Аристарх Павлов"
# invoice "11-2" "Геннадий Покемонов"
# passport "7874 342546" "Aydar Yulchurin"
# ----------------------------------------------
# ...

# %% [markdown]
# Необходимо реализовать пользовательские команды (внимание! это не название функций, которые должны быть выразительными, а команды, которые вводит пользователь, чтобы получить необходимый результат):
#
# * p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит;
# * s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится
# Правильно обработайте ситуации, когда пользователь будет вводить несуществующий документ.
# * l – list – команда, которая выведет список всех документов в формате
# **passport "2207 876234" "Василий Гупкин"**
# * as – add shelf – команда, которая спросит номер новой полки и добавит ее в перечень. Предусмотрите случай, когда пользователь добавляет полку, которая уже существует.
# * d – delete – команда, которая спросит номер документа и удалит его из каталога и из перечня полок. Предусмотрите сценарий, когда пользователь вводит несуществующий документ;
# * m – move – команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую. Корректно обработайте кейсы, когда пользователь пытается переместить несуществующий документ или переместить документ на несуществующую полку;
# *  add – команда, которая добавит новый документ в каталог и в перечень полок, спросив его номер, тип, имя владельца и номер полки, на котором он будет храниться. Корректно обработайте ситуацию, когда пользователь будет пытаться добавить документ на несуществующую полку.
