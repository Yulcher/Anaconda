# %% [markdown]
# **Задание 1**
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %%
import pandas as pd
ratings = pd.read_csv('ratings.csv')

# %%
ratings[:5]
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
ratings.query(f'rating == {format(5.0)}')['movieId'].value_counts().head(10)
# Out:
# 318     153
# 296     123
# 356     116
# 2571    109
# 260     104
# 593      92
# 527      92
# 858      88
# 2959     81
# 1196     80
# Name: movieId, dtype: int64

# %% [markdown]
# **Задание 2**
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %%
power = pd.read_csv('power.csv')
power.head()
# Out:
#    country  year  quantity  category
# 0  Austria  1996       5.0         1
# 1  Austria  1995      17.0         1
# 2  Belgium  2014       0.0         1
# 3  Belgium  2013       0.0         1
# 4  Belgium  2012      35.0         1

# %%
filtered_power = power.query('country == ["Latvia", "Lithuania", "Estonia"] & category == [4, 12, 21] & year >= 2005 & year <= 2010 & quantity > 0')
filtered_power
# Out:
#           country  year  quantity  category
# 10617     Estonia  2008       1.0         4
# 10620     Estonia  2005       1.0         4
# 11156   Lithuania  2008       1.0         4
# 11158   Lithuania  2006       1.0         4
# 11159   Lithuania  2005       1.0         4
# ...           ...   ...       ...       ...
# 253982  Lithuania  2009      98.0        21
# 253983  Lithuania  2008      54.0        21
# 253984  Lithuania  2007      47.0        21
# 253985  Lithuania  2006      31.0        21
# 253986  Lithuania  2005       1.0        21
#
# [347 rows x 4 columns]

# %%
filtered_power['quantity'].sum
# Out:
# <bound method Series.sum of 10617      1.0
# 10620      1.0
# 11156      1.0
# 11158      1.0
# 11159      1.0
#           ...
# 253982    98.0
# 253983    54.0
# 253984    47.0
# 253985    31.0
# 253986     1.0
# Name: quantity, Length: 347, dtype: float64>

# %% [markdown]
# **Задание 3**
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe. Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %%
page_url = 'https://infotables.ru/meditsina/1198-koronavirus-v-rossii'
course = pd.read_html(page_url, attrs = {'class': 'tables90'}, encoding='utf-8')
course[0].head(10)
# Out:
#      0                                              1               2  \
# 0    №  Города России с корона­вирусом и субъ­екты РФ     Забо­левшие
# 1  NaN                                 РОССИЯ (Всего)  1547774 +16550
# 2    1                                         Москва    405352 +4312
# 3    2                             Московская область      84743 +496
# 4    3                                Санкт-Петербург      58236 +721
# 5    4                          Нижегородская область      40005 +369
# 6    5                           Свердловская область      35069 +287
# 7    6                             Ростовская область      29369 +311
# 8    7                            Ханты-Мансийский АО      27481 +194
# 9    8                              Красноярский край      25293 +277
#
#          3             4        5
# 0  Умер­ли  Выздо­ровели  На 1000
# 1    26589       1158940      105
# 2     6503        296474      319
# 3     1563         63067      110
# ...

# %% [markdown]
# **Задание 4**
# Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
# - оценка 2 и меньше - низкий рейтинг
# - оценка 4 и меньше - средний рейтинг
# - оценка 4.5 и 5 - высокий рейтинг
#
# Результат классификации запишите в столбец class

# %%
def func(rating):
    if rating <= 2:
        return 'низкий рейтинг'
    if rating < 4.5:
        return 'средний рейтинг'
    if rating >= 4.5 and rating <= 5:
        return 'высокий рейтинг'
    return 'Ошибка'

def cl():
    movies = pd.read_csv('movies.csv')
    classified = ratings.merge(movies, on=["movieId"], how='right').pivot_table(index=['title','movieId'], values = 'rating', aggfunc='mean')
    classified['class'] = classified['rating'].apply(func)
    print(classifiedRating.head(-10))
cl()
# Out:
#                                                    rating            class
# title                                   movieId
# '71 (2014)                              117867   4.000000  средний рейтинг
# 'Hellboy': The Seeds of Creation (2004) 97757    4.000000  средний рейтинг
# 'Round Midnight (1986)                  26564    3.500000  средний рейтинг
# 'Salem's Lot (2004)                     27751    5.000000  высокий рейтинг
# 'Til There Was You (1997)               779      4.000000  средний рейтинг
# ...                                                   ...              ...
# Zoolander 2 (2016)                      148888   2.500000  средний рейтинг
# Zoom (2006)                             47384    2.500000  средний рейтинг
# Zoom (2015)                             156553   2.500000  средний рейтинг
# Zootopia (2016)                         152081   3.890625  средний рейтинг
# Zulu (1964)                             5899     4.000000  средний рейтинг
#
# ...

# %% [markdown]
# **Задание 5**
# Используем файл keywords.csv.
#
# Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному
# региону. Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона.
# Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
#
# geo_data = {
# 'Центр': ['москва', 'тула', 'ярославль'],
# 'Северо-Запад': ['петербург', 'псков', 'мурманск'],
# 'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
# }
#
# Результат классификации запишите в отдельный столбец region.

# %%
keywords = pd.read_csv('keywords.csv')
geo_data = {'Центр': ['москва', 'тула', 'ярославль'], 
            'Северо-Запад': ['петербург', 'псков', 'мурманск'], 
            'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск'] }

# %%
keywords.head()
# Out:
#          keyword     shows
# 0             вк  64292779
# 1  одноклассники  63810309
# 2          порно  41747114
# 3           ютуб  39995567
# 4      вконтакте  21014195

# %%
def func(keyword):
    for region in geo_data:
        if keyword in region:
            return region
    return 'undefined'

# %%
keywords['region'] = keywords['keyword'].apply(func)

# %%
keywords.head(10)
# Out:
#                       keyword     shows     region
# 0                          вк  64292779  undefined
# 1               одноклассники  63810309  undefined
# 2                       порно  41747114  undefined
# 3                        ютуб  39995567  undefined
# 4                   вконтакте  21014195  undefined
# 5  одноклассники моя страница  19976138  undefined
# 6                        майл  15144673  undefined
# 7                       авито  14786593  undefined
# 8                  переводчик  14453469  undefined
# 9                      яндекс  13344734  undefined

# %% [markdown]
# **Задание 6**
# Есть мнение, что “раньше снимали настоящее кино, не то что сейчас”. Ваша задача проверить это утверждение, используя файлы
# с рейтингами фильмов из прошлого домашнего занятия (файл ratings.csv из базы https://grouplens.org/datasets/movielens). Т. е. проверить верно ли, что с ростом года выпуска фильма его средний рейтинг становится ниже.
#
# При этом мы не будем затрагивать субьективные факторы выставления этих рейтингов, а пройдемся по следующему алгоритму:
#
# В переменную years запишите список из всех годов с 1950 по 2010.
#
# Напишите функцию production_year, которая каждой строке из названия фильма выставляет год выпуска. Не все названия фильмов содержат год выпуска в одинаковом формате, поэтому используйте следующий алгоритм:
#
# для каждой строки пройдите по всем годам списка years
# если номер года присутствует в названии фильма, то функция возвращает этот год как год выпуска
# если ни один из номеров года списка years не встретился в названии фильма, то возвращается 1900 год
# Запишите год выпуска фильма по алгоритму пункта 2 в новый столбец ‘year’
#
# Посчитайте средний рейтинг всех фильмов для каждого значения столбца ‘year’ и отсортируйте результат по убыванию рейтинга

# %%
movies = pd.read_csv('movies.csv')

# %%
ratings.head(10)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# 5       1       70     3.0  964982400
# 6       1      101     5.0  964980868
# 7       1      110     4.0  964982176
# 8       1      151     5.0  964984041
# 9       1      157     5.0  964984100

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
table = movies.merge(ratings)

# %%
table.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp
# 0       1     4.0   964982703
# 1       5     4.0   847434962
# 2       7     4.5  1106635946
# 3      15     2.5  1510577970
# 4      17     4.5  1305696483

# %%
years = [x for x in range(1950,2010)]

# %%
def production_year(title):
    for year in years:
        if str(year) in title:
            return year
    return 1900

# %%
table['year'] = table['title'].apply(production_year)

# %%
table.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 2        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 3        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 4        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId  rating   timestamp  year
# 0       1     4.0   964982703  1995
# 1       5     4.0   847434962  1995
# 2       7     4.5  1106635946  1995
# 3      15     2.5  1510577970  1995
# 4      17     4.5  1305696483  1995

# %%
table2 = table.pivot_table(index = ['year'], values = 'rating', aggfunc='mean')
table2.head()
# Out:
#         rating
# year
# 1900  3.542858
# 1950  3.813665
# 1951  3.804945
# 1952  3.953125
# 1953  3.647059

# %%
table2.sort_values(by = ['rating'], ascending = False).head(10)
# Out:
#         rating
# year
# 1957  4.039535
# 1954  4.009191
# 1962  3.969466
# 1952  3.953125
# 1972  3.944293
# 1964  3.940160
# 1974  3.935622
# 1967  3.922572
# 1975  3.879121
# 1958  3.842424
